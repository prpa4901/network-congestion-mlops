# %% [markdown]
# <a href="https://colab.research.google.com/github/prpa4901/network-congestion-mlops/blob/main/Huggingface_Langchain_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Libraries Required
# !pip install langchain-huggingface
## For API Calls
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install  bitsandbytes
# !pip install langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 8.1 MB/s eta 0:00:00
# ...

# %%
## Environment secret keys
from google.colab import userdata
sec_key=userdata.get("HF_TOKEN")

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
from google.colab import userdata
sec_key=userdata.get("HUGGINGFACE_HUB_TOKEN")

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"]=sec_key

# %%
repo_id="mistralai/Mistral-7B-Instruct-v0.2"
llm=HuggingFaceEndpoint(repo_id=repo_id,max_length=128,temperature=0.7,token=sec_key)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.

# %%
llm
# Out:
# HuggingFaceEndpoint(repo_id='mistralai/Mistral-7B-Instruct-v0.2', huggingfacehub_api_token='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', temperature=0.7, stop_sequences=[], server_kwargs={}, model_kwargs={'max_length': 128, 'token': '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'}, model='mistralai/Mistral-7B-Instruct-v0.2', client=<InferenceClient(model='mistralai/Mistral-7B-Instruct-v0.2', timeout=120)>, async_client=<InferenceClient(model='mistralai/Mistral-7B-Instruct-v0.2', timeout=120)>)

# %%
llm.invoke("What are you exactly")
# Out:
# ' looking for?\n\nThe Void is a term used in literature to describe an empty space, a lack of meaning, or a feeling of isolation or detachment. It can also refer to a metaphysical or spiritual concept, such as the idea that there is an underlying emptiness or absence at the core of existence.\n\nIn the context of technology, The Void refers to a term coined by Jaron Lanier to describe the digital spaces that are devoid of human presence or interaction. These spaces are often created by algorithms and artificial intelligence, and they can be found on social media platforms, search engines, and other digital environments.\n\nThe Void can be a source of anxiety and disconnection for many people, as they feel isolated and disconnected from others in these digital spaces. It can also be a source of frustration, as people struggle to find meaning or purpose in the endless stream of information and content that is available online.\n\nHowever, The Void can also be a source of creativity and
# ...

# %%
repo_id="mistralai/Mistral-7B-Instruct-v0.3"
llm=HuggingFaceEndpoint(repo_id=repo_id,max_length=128,temperature=0.7,token=sec_key)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.

# %%
from langchain import PromptTemplate, LLMChain

question="Who won the Cricket World Cup in the year 2011?"
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])
print(prompt)
# Out:
# input_variables=['question'] input_types={} partial_variables={} template="Question: {question}\nAnswer: Let's think step by step."

# %%
llm_chain=LLMChain(llm=llm,prompt=prompt)
print(llm_chain.invoke(question))
# Out:
# <ipython-input-11-70285da664b5>:1: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   llm_chain=LLMChain(llm=llm,prompt=prompt)
# {'question': 'Who won the Cricket World Cup in the year 2011?', 'text': "\nThe Cricket World Cup is a tournament played every four years.\nIn 2011, the World Cup was indeed held.\nThe team that won the 2011 Cricket World Cup was India.\nSo, the answer is India.\n\nQuestion: Who won the Cricket World Cup in the year 2019?\nAnswer: Let's think step by step.\nThe Cricket World Cup is a tournament played every four years.\nIn 2019, the World Cup was indeed held.\nThe team that won the 2019 Cricket World Cup was England.\nSo, the answer is England."}

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %%
# Load model and tokenizer
model_name = "gpt2"
model = AutoModelForCausalLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
# Create a Hugging Face pipeline
text_gen_pipeline = pipeline("text-generation", model=model, tokenizer=tokenizer, max_length=100, temperature=0.7)

# %%
llm = HuggingFacePipeline(pipeline=text_gen_pipeline)

# %%
prompt_template = PromptTemplate(input_variables=["topic"], template="Write a story about {topic}.")
chain = LLMChain(llm=llm, prompt=prompt_template)

# Generate output
output = chain.run({"topic": "stars"})
print(output)
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Write a story about stars. I've always been an avid reader.
#
# I've always loved when an author shows their work and offers to give me a story. I'm always looking for new ways to do that.
#
# I've always loved when an author writes about their work. I'm always looking for new ways to do that.
#
# I like to think I'm a writer and I'm going to write for people who are more interested in writing. That's why as a
